# %%
count = 0
win=open('/中獎號碼.txt').read().split()
mine=open('/我的發票.txt').read().split()

for i, num in enumerate(mine):
  if num in win:
    print('第',i+1,'張發票對中號碼',num,"!")
    count = count + 1
print('共',count,'張發票中獎,總共獲得',count*200,'元')
# Out:
# 第 4 張發票對中號碼 847 !
# 第 6 張發票對中號碼 187 !
# 共 2 張發票中獎,總共獲得 400 元
