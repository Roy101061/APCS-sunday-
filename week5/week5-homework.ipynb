# %%
import csv

with open('/地址資料.csv') as infile:
  data = list(csv.DictReader (infile))
  for e in data:
    print ('原始資料:', e['姓名'], e['縣市'], e['住址'])
    if e['縣市'] [0] == '台':
      e['縣市'] = '臺'+e['縣市'] [1:]
    if 'F' in e['住址']:
      e['住址'] == e['住址'].replace('F', '樓')
    if e['縣市'] == '臺中市' and '中港路' in e['住址']:
      e['住址'] = e['住址'].replace('中港路', '臺灣大道')
    e['住址'] = e['縣市']+e['住址']

    print ('更新資料:', e['姓名'], e['縣市'], e['住址'])
with open('/新地址資料.csv', 'w', newline='') as outfile:
  writer = csv.DictWriter (outfile, fieldnames = data [0].keys () )
  writer.writeheader ()
  for e in data:
    writer.writerow (e)
# Out:
# 原始資料: 陳大明 台北市 汀州路四段88號
# 更新資料: 陳大明 臺北市 臺北市汀州路四段88號
# 原始資料: 張小華 臺北市 和平東路一段162號
# 更新資料: 張小華 臺北市 臺北市和平東路一段162號
# 原始資料: 李國華 台北市 復興南路一段6號8樓
# 更新資料: 李國華 臺北市 臺北市復興南路一段6號8樓
# 原始資料: 朱志清 台中市 大仁路38巷4號5F
# 更新資料: 朱志清 臺中市 臺中市大仁路38巷4號5F
# 原始資料: 朱婷婷 台中市 中港路29號2樓
# 更新資料: 朱婷婷 臺中市 臺中市臺灣大道29號2樓
# 原始資料: 周杰倫 台南市 中港路四段390-1號
# 更新資料: 周杰倫 臺南市 臺南市中港路四段390-1號
# 原始資料: 劉德明 高雄市 三多路49巷2弄1號14F
# 更新資料: 劉德明 高雄市 高雄市三多路49巷2弄1號14F
# 原始資料: 紀小月 台東市 中台五路95號
# 更新資料: 紀小月 臺東市 臺東市中台五路95號
