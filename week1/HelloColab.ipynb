# %%
a=3
b='abcd'
print(a*3)
print(b*3)
# Out:
# 9
# abcdabcdabcd

# %%
x=2
y=-1
z=x>3 and y<0
u=x>3 or y<0
print(z)
print(u)
# Out:
# False
# True

# %%
a="string"
b=1
c=3.3
d=True
e=[1,2,3]

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'list'>

# %%
pi=3.1415926
print(pi)
# Out:
# 3.1415926

# %%
x=2030
x=x+3
print(x)
# Out:
# 2033

# %%
x='today is '
y='424'
print(x+y)
# Out:
# today is 424

# %%
x='today is '
y=424
print(x+y)

# error occur!!!

# %%
a='Hello'
b='World'
print(a,b,sep="|")
# Out:
# Hello|World

# %%
a='Hello'
b='World'
print(a,end='\n')
print(b,end="\n")
# Out:
# Hello
# World

# %%
a='apple'
b='banana'
c='cherry'
d='dragon fruit'
print(a,b,c,d,sep=',',end='.')
# Out:
# apple,banana,cherry,dragon fruit.
